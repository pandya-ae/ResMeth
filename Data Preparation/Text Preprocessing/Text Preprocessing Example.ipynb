# %% [markdown]
# # Dasar Text-Preprocessing dengan Python#

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ## Tokenizing: Sentences Tokenizing Using NLTK Module ##
# Memisahkan kalimat dalam sebuah paragraf.

# %%
from nltk.tokenize import sent_tokenize

kalimat = "Andi kerap melakukan transaksi rutin secara daring atau online. Menurut Andi belanja online lebih praktis & murah."
 
tokens = nltk.tokenize.sent_tokenize(kalimat)
print(tokens)
# Out:
# ['Andi kerap melakukan transaksi rutin secara daring atau online.', 'Menurut Andi belanja online lebih praktis & murah.']

# %% [markdown]
# ## Case Folding: Lowercase ##
# Merubah format teks menjadi format huruf kecil semua (_lowercase_).

# %%
kalimat = "Berikut ini adalah 5 negara dengan pendidikan terbaik di dunia adalah Korea Selatan, Jepang, Singapura, Hong Kong, dan Finlandia."
lower_case = kalimat.lower()
print(lower_case)
# Out:
# berikut ini adalah 5 negara dengan pendidikan terbaik di dunia adalah korea selatan, jepang, singapura, hong kong, dan finlandia.

# %% [markdown]
# ## Case Folding: Removing Number ##
# Menghapus karakter angka.

# %%
import re 

kalimat = "Berikut ini adalah 5 negara dengan pendidikan terbaik di dunia adalah Korea Selatan, Jepang, Singapura, Hong Kong, dan Finlandia."
hasil = re.sub(r"\d+", "", kalimat)
print(hasil)
# Out:
# Berikut ini adalah  negara dengan pendidikan terbaik di dunia adalah Korea Selatan, Jepang, Singapura, Hong Kong, dan Finlandia.

# %% [markdown]
# ## Case Folding: Removing Punctuation ##
# Menghapus karakter tanda baca.

# %%
kalimat = "Ini &adalah [contoh] kalimat? {dengan} tanda. baca?!!"
hasil = re.sub(r'[^\w\s]', '', kalimat)
print(hasil)
# Out:
# Ini adalah contoh kalimat dengan tanda baca

# %% [markdown]
# ## Case Folding: Removing Whitespace ##
# Menghapus karakter kosong.

# %%
kalimat = " \t ini kalimat contoh   \t "
hasil1 = kalimat.strip()
hasil2 = kalimat.lstrip()
print(hasil1)
print(hasil2)
# Out:
# ini kalimat contoh
# ini kalimat contoh

# %% [markdown]
# ## Separating Sentences with Split () Method ##
# Fungsi `split()` memisahkan _string_ ke dalam _list_ dengan spasi sebagai pemisah jika tidak ditentukan pemisahnya.
#
# https://www.w3schools.com/python/ref_string_split.asp

# %%
kalimat = "rumah idaman adalah rumah yang bersih"
pisah = kalimat.split()
print(pisah)
# Out:
# ['rumah', 'idaman', 'adalah', 'rumah', 'yang', 'bersih']

# %% [markdown]
# ## Tokenizing: Word Tokenizing Using NLTK Module ##
# Menggunakan _library_ NLTK untuk memisahkan kata dalam sebuah kalimat.

# %%
from nltk.tokenize import word_tokenize 
 
kalimat = "Andi kerap melakukan transaksi rutin secara daring atau online."

tokens = nltk.tokenize.word_tokenize(kalimat)
print(tokens)
# Out:
# ['Andi', 'kerap', 'melakukan', 'transaksi', 'rutin', 'secara', 'daring', 'atau', 'online', '.']

# %% [markdown]
# ## Tokenizing with Case Folding ##
# Menggabungkan teknik _Case Foling_ dengan _Tokenizing_.

# %%
from nltk.tokenize import word_tokenize 
 
kalimat = "Andi kerap melakukan transaksi rutin secara daring atau online."
kalimat = re.sub(r'[^\w\s]', '', kalimat).lower()
 
tokens = nltk.tokenize.word_tokenize(kalimat)
print(tokens)
# Out:
# ['andi', 'kerap', 'melakukan', 'transaksi', 'rutin', 'secara', 'daring', 'atau', 'online']

# %% [markdown]
# ## Filtering using NLTK: Stopword List ##

# %%
nltk.download('stopwords')
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

listStopword =  set(stopwords.words('indonesian'))
 
print(listStopword)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# {'mampu', 'dibuatnya', 'mendapat', 'sebegini', 'kedua', 'ditandaskan', 'menanti', 'terbanyak', 'sedikitnya', 'berdatangan', 'pasti', 'berupa', 'dimaksud', 'toh', 'wong', 'begitulah', 'menunjuki', 'tunjuk', 'terus', 'sejenak', 'tidakkah', 'beginilah', 'mampukah', 'berbagai', 'lainnya', 'pak', 'beginikah', 'mempergunakan', 'kami', 'sesuatunya', 'berkehendak', 'sesaat', 'kata', 'berlangsung', 'diberikan', 'sebetulnya', 'kalian', 'ini', 'sebegitu', 'manalagi', 'berapa', 'mengingat', 'dipergunakan', 'mau', 'wah', 'serta', 'sekali-kali', 'hendaknya', 'bekerja', 'menginginkan', 'walaupun', 'memintakan', 'pentingnya', 'dapat', 'tambah', 'sesama', 'bagaikan', 'entah', 'tidaklah', 'ditunjukkan', 'menurut', 'seterusnya', 'sebuah', 'sekadarnya', 'merekalah', 'juga', 'antara', 'bukan', 'kepada', 'dia', 'persoalan', 'sekarang', 'berakhir', 'setelah', 'teringat', 'bung', 'seolah-olah', 'segalanya', 'lah', 'mendapatkan', 'bermacam-macam', 'sering', 'pantas', 'demikian', 'memungkinkan', 'masalahnya', 'dijelaskan', 'tempat', 'beri', 'kira-kira', 'memperbuat', 'para', 'bersiap-siap', 'mendatangi', 'tersampaikan', 'diperlihatkan', 'agaknya', 'merasa', 'rata', 'sekurang-kurangnya', 'disebutkan', 'dijelaskannya', 'bakal', 'seluruh', 'bila', 'maka', 'jumlah', 'kesampaian', 'berkeinginan', 'diperbuat', 'lalu', 'selaku', 'tertuju', 'sesampai', 'menanyai', 'tambahnya', 'sebagainya', 'dirinya', 'kembali', 'perlukah', 'seperti', 'apa', 'siapa', 'dikarenakan', 'begitu', 'kenapa', 'bagaimanapun', 'dan', 'malah', 'seolah', 'terjadi', 'terlalu', 'ternyata', 'didatangkan', 'lamanya', 'diibaratkan', 'sementara', 'sebutlah', 'menegaskan', 'nantinya', 'disebut', 'menyatakan', 'suatu', 'tanyanya', 'sebesar', 'akankah', 'justru', 'semula', 'dikatakannya', 'dipastikan', 'bukanlah', 'sebisanya', 'kebetulan', 'secara', 'mengapa', 'ibarat', 'diantaranya', 'jelaskan', 'mendatangkan', 'itulah', 'menyampaikan', 'seberapa', 'begitukah', 'tersebutlah', 'supaya', 'dituturkan', 'dimisalkan', 'kapan', 'kelihatannya', 'kiranya', 'katakan', 'di', 'setidak-tidaknya', 'beginian', 'dikira', 'berikan', 'meski', 'sewaktu', 'setempat', 'terutama', 'seenaknya', 'sepanjang', 'ataukah', 'perlunya', 'atau', 'semampu', 'semakin', 'bahwasanya', 'akulah', 'disinilah', 'maupun', 'se', 'sendiri', 'bawah', 'akhiri', 'dahulu', 'olehnya', 'cukup', 'inikah', 'harus', 'kasus', 'jumlahnya', 'sejumlah', 'walau', 'belakang', 'selama-lamanya', 'kitalah', 'paling', 'dengan', 'hanya', 'menjawab', 'jikalau', 'tentu', 'sebelum', 'menjadi', 'segala', 'tengah', 'kecil', 'kan', 'sebutnya', 'sebelumnya', 'tampak', 'ditujukan', 'mengibaratkan', 'menanya', 'penting', 'kepadanya', 'khususnya', 'tanya', 'lanjut', 'kira', 'beberapa', 'benar', 'diibaratkannya', 'enggak', 'meyakini', 'sepantasnya', 'seperlunya', 'terjadilah', 'disampaikan', 'jawaban', 'jawabnya', 'sejak', 'soalnya', 'itu', 'berikut', 'rupanya', 'setiba', 'sekalipun', 'tiga', 'lanjutnya', 'akhir', 'asalkan', 'mendatang', 'kamilah', 'diperlukan', 'bukankah', 'mengatakannya', 'mempertanyakan', 'secukupnya', 'berturut-turut', 'haruslah', 'satu', 'pertama', 'jelaslah', 'apabila', 'seluruhnya', 'bersama', 'padanya', 'semampunya', 'terakhir', 'kamu', 'baru', 'hampir', 'kelihatan', 'pula', 'betulkah', 'sedangkan', 'hal', 'inginkan', 'pihak', 'tetap', 'pun', 'ialah', 'memang', 'ditunjuknya', 'sangat', 'menjelaskan', 'selama', 'ucap', 'awalnya', 'belum', 'awal', 'terasa', 'ungkapnya', 'seorang', 'dini', 'sekalian', 'tadinya', 'yakni', 'dulu', 'meyakinkan', 'naik', 'sebut', 'apalagi', 'sangatlah', 'masalah', 'manakala', 'umum', 'janganlah', 'enggaknya', 'hingga', 'semuanya', 'keseluruhan', 'kurang', 'sesudahnya', 'macam', 'dekat', 'jika', 'memperkirakan', 'mulailah', 'rasanya', 'depan', 'telah', 'mengungkapkan', 'diucapkan', 'berkali-kali', 'dilakukan', 'tampaknya', 'hendaklah', 'siapapun', 'daripada', 'lain', 'per', 'dipertanyakan', 'sudah', 'inilah', 'sajalah', 'misal', 'sampaikan', 'diperlukannya', 'ibu', 'tanpa', 'cukuplah', 'diingatkan', 'jawab', 'memasti ...

# %% [markdown]
# ## Filtering using NLTK ##
# Melihat daftar stopword pada NLTK (Indonesia).

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
 
kalimat = "Andi kerap melakukan transaksi rutin secara daring atau online. Menurut Andi belanja online lebih praktis & murah."
kalimat = re.sub(r'[^\w\s]', '', kalimat).lower()
 
tokens = word_tokenize(kalimat)
listStopword =  set(stopwords.words('indonesian'))
 
removed = []
for t in tokens:
    if t not in listStopword:
        removed.append(t)
 
print(removed)
# Out:
# ['andi', 'kerap', 'transaksi', 'rutin', 'daring', 'online', 'andi', 'belanja', 'online', 'praktis', 'murah']

# %% [markdown]
# ## Filtering using Sastrawi: Stopword List ##
# Melihat daftar _stopword_ pada Sastrawi.

# %%
# !pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 11.8 MB/s
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
 
factory = StopWordRemoverFactory()
stopwords = factory.get_stop_words()
print(stopwords)
# Out:
# ['yang', 'untuk', 'pada', 'ke', 'para', 'namun', 'menurut', 'antara', 'dia', 'dua', 'ia', 'seperti', 'jika', 'jika', 'sehingga', 'kembali', 'dan', 'tidak', 'ini', 'karena', 'kepada', 'oleh', 'saat', 'harus', 'sementara', 'setelah', 'belum', 'kami', 'sekitar', 'bagi', 'serta', 'di', 'dari', 'telah', 'sebagai', 'masih', 'hal', 'ketika', 'adalah', 'itu', 'dalam', 'bisa', 'bahwa', 'atau', 'hanya', 'kita', 'dengan', 'akan', 'juga', 'ada', 'mereka', 'sudah', 'saya', 'terhadap', 'secara', 'agar', 'lain', 'anda', 'begitu', 'mengapa', 'kenapa', 'yaitu', 'yakni', 'daripada', 'itulah', 'lagi', 'maka', 'tentang', 'demi', 'dimana', 'kemana', 'pula', 'sambil', 'sebelum', 'sesudah', 'supaya', 'guna', 'kah', 'pun', 'sampai', 'sedangkan', 'selagi', 'sementara', 'tetapi', 'apakah', 'kecuali', 'sebab', 'selain', 'seolah', 'seraya', 'seterusnya', 'tanpa', 'agak', 'boleh', 'dapat', 'dsb', 'dst', 'dll', 'dahulu', 'dulunya', 'anu', 'demikian', 'tapi', 'ingin', 'juga', 'nggak', 'mari', 'nanti', 'melainkan', 'oh', 'ok', 'seharusnya', 'sebetulnya', 'setiap', 'setidaknya', 'sesuatu', 'pasti', 'saja', 'toh', 'ya', 'walau', 'tolong', 'tentu', 'amat', 'apalagi', 'bagaimanapun']

# %% [markdown]
# ## Filtering using Sastrawi ##

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from nltk.tokenize import word_tokenize 

factory = StopWordRemoverFactory()
stopword = factory.create_stop_word_remover()

kalimat = "Andi kerap melakukan transaksi rutin secara daring atau online. Menurut Andi belanja online lebih praktis & murah."
kalimat = re.sub(r'[^\w\s]', '', kalimat).lower()

stop = stopword.remove(kalimat)
tokens = nltk.tokenize.word_tokenize(stop)

print(tokens)
# Out:
# ['andi', 'kerap', 'melakukan', 'transaksi', 'rutin', 'daring', 'online', 'andi', 'belanja', 'online', 'lebih', 'praktis', 'murah']

# %% [markdown]
# ## Add Custom Stopword ##
# Menambahkan kata di _stopword_ untuk dihilangkan pada sebuah teks.

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, StopWordRemover, ArrayDictionary
from nltk.tokenize import word_tokenize 
    
# ambil stopword bawaan
stop_factory = StopWordRemoverFactory().get_stop_words()
more_stopword = ['daring', 'online']

kalimat = "Andi kerap melakukan transaksi rutin secara daring atau online. Menurut Andi belanja online lebih praktis & murah."
kalimat = re.sub(r'[^\w\s]', '', kalimat).lower()

# menggabungkan stopword
data = stop_factory + more_stopword
 
dictionary = ArrayDictionary(data)
str = StopWordRemover(dictionary)
tokens = nltk.tokenize.word_tokenize(str.remove(kalimat))
 
print(tokens)
# Out:
# ['andi', 'kerap', 'melakukan', 'transaksi', 'rutin', 'daring', 'andi', 'belanja', 'online', 'lebih', 'praktis', 'murah']

# %% [markdown]
# ## Stemming : Porter Stemming Algorithm using NLTK (English) ##
#
# https://tartarus.org/martin/PorterStemmer/index-old.html

# %%
from nltk.stem import PorterStemmer    
ps = PorterStemmer() 

kata = ["program", "programs", "programer", "programing", "programers"] 
  
for k in kata: 
    print(k, " : ", ps.stem(k))
# Out:
# program  :  program
# programs  :  program
# programer  :  program
# programing  :  program
# programers  :  program

# %% [markdown]
# ## Stemming Bahasa Indonesia using Sastrawi ##

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()
 
kalimat = "Andi kerap melakukan transaksi rutin secara daring atau online. Menurut Andi belanja online lebih praktis & murah."

hasil = stemmer.stem(kalimat)
print(hasil)
# Out:
# andi kerap laku transaksi rutin cara daring atau online turut andi belanja online lebih praktis murah

# %% [markdown]
# ## Frequency Distribution ##
# Menghitung frekuensi kemunculan setiap tokens(kata) dalam teks.

# %%
import string
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

kalimat = "Andi kerap melakukan transaksi rutin secara daring atau online. Menurut Andi belanja online lebih praktis & murah."
kalimat = re.sub(r'[^\w\s]', '', kalimat).lower()
 
tokens = nltk.tokenize.word_tokenize(kalimat)
kemunculan = nltk.FreqDist(tokens)
print(kemunculan.most_common())
# Out:
# [('andi', 2), ('online', 2), ('kerap', 1), ('melakukan', 1), ('transaksi', 1), ('rutin', 1), ('secara', 1), ('daring', 1), ('atau', 1), ('menurut', 1), ('belanja', 1), ('lebih', 1), ('praktis', 1), ('murah', 1)]

# %% [markdown]
# ## Frequency Distribution Visualization with Matplotlib ##
# Untuk menggambarkan frekuensi kemunculan setiap tokens dapat menggunakan _library_ __matplotlib__ pada Python.
#
# https://matplotlib.org

# %%
import matplotlib.pyplot as plt

kemunculan.plot(30,cumulative=False)
plt.show()
